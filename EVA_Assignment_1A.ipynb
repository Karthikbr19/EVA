# %%
# import the necessary packages
import numpy as np
from urllib.request import urlopen
import cv2
from matplotlib import pyplot as plt

# METHOD #1: OpenCV, NumPy, and urllib
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
#image = url_to_image("https://fontsarena-cd5e.kxcdn.com/wp-content/uploads/2019/04/helvetica-now-font-400x364.png")
image = url_to_image("https://1.bp.blogspot.com/-gHAJiBG1Aa0/WWCAle4H5KI/AAAAAAAAPug/XgIWOQdS-Kw3jpCq4IWM2VCi2UtSlmQQgCLcBGAs/s400/water-nature-walls-pics.jpg")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F0D7F151FD0>

# %%
edges = cv2.Canny(image,100,200)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x7F0D7D8170B8>

# %% [markdown]
# ## Horizontal Edge Detector

# %%
kernel = np.float32([[-1,-2,-1],[0,0,0],[1,2,1]])
dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F0D7D8195C0>

# %% [markdown]
# ## 45 Degree Angle Detector

# %%
kernel = np.float32([[-1,-1,2],[-1,2,-1],[2,-1,-1]])
dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F0D7D816748>

# %% [markdown]
# ## Blur Kernel

# %%
kernel = np.float32([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]])
dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F0D7D815A20>

# %% [markdown]
# ## Sharpen Kernel

# %%
kernel = np.float32([[0,-1,0],[-1,5,-1],[0,-1,0]])
dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F0D7D81A630>

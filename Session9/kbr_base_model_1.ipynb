# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, AveragePooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras import regularizers

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# # 6A Model

# %%
# Define the model


model = Sequential()
model.add(Convolution2D(32, 3, 3, activation='relu', border_mode='same',kernel_regularizer=regularizers.l2(0.001), input_shape=(32, 32, 3)))
model.add(BatchNormalization())

model.add(Convolution2D(48, 3, 3, activation='relu', border_mode='same',kernel_regularizer=regularizers.l2(0.001), input_shape=(32, 32, 3)))
model.add(BatchNormalization())

model.add(Convolution2D(64, 3,3, activation='relu',  kernel_regularizer=regularizers.l2(0.001),border_mode='same'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(32, 1, 1))

model.add(Convolution2D(32, 3, 3, activation='relu', border_mode='same',kernel_regularizer=regularizers.l2(0.001), input_shape=(32, 32, 3)))
model.add(BatchNormalization())

model.add(Convolution2D(64, 3, 3, activation='relu', kernel_regularizer=regularizers.l2(0.001),border_mode='same'))
model.add(BatchNormalization())

model.add(Convolution2D(128, 3, 3, activation='relu', kernel_regularizer=regularizers.l2(0.001),border_mode='same'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(32, 1, 1))

model.add(Convolution2D(128, 3, 3, activation='relu', kernel_regularizer=regularizers.l2(0.001), border_mode='same'))
model.add(BatchNormalization())

model.add(Convolution2D(256, 3, 3, kernel_regularizer=regularizers.l2(0.001), border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(10, 1, 1))

model.add(AveragePooling2D(pool_size = (4,4)))
model.add(Flatten())
model.add(Activation('softmax'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0701 11:18:10.812760 139892582700928 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", kernel_regularizer=<keras.reg..., input_shape=(32, 32, 3..., padding="same")`
#   after removing the cwd from sys.path.
# W0701 11:18:10.849112 139892582700928 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0701 11:18:10.854726 139892582700928 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0701 11:18:10.901258 139892582700928 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0701 11:18:10.902185 139892582700928 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0701 11:18:13.504601 139892582700928 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), activation="relu", kernel_regularizer=<keras.reg..., input_shape=(32, 32, 3..., padding="same")`
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", kernel_regularizer=<keras.reg..., padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# W0701 11:18:13.851801 139892582700928 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", kernel_regularizer=<keras.reg..., input_shape=(32, 32, 3..., padding="same")`
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# W0701 11:18:14.378108 139892582700928 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 48)        13872
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 48)        192
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        27712
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 32)          4128
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 128)         36992
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_1 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 10)          2570
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 488,026
# Trainable params: 486,522
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from keras.callbacks import ModelCheckpoint

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


best_model_weights = '6A_retrained_best_weights.h5'
checkpointer = ModelCheckpoint(filepath='../content/drive/My Drive/EVA/Saved_models/'+best_model_weights, monitor='val_acc', mode='auto', verbose = 1, save_best_only=True)
# Out:
# W0701 11:19:59.590688 139892582700928 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
  return round(0.008 * 1/(1 + 0.30* epoch), 10)

datagen = ImageDataGenerator(rotation_range=5,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.15,zoom_range=0.07,horizontal_flip=False)

# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels),callbacks=[LearningRateScheduler(scheduler, verbose=1),checkpointer],verbose=1)

end = time.time()
  
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history

plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., verbose=1, steps_per_epoch=390, epochs=100)`
#   app.launch_new_instance()
# W0701 11:20:01.861271 139892582700928 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.008.
# 390/390 [==============================] - 33s 85ms/step - loss: 2.2603 - acc: 0.3425 - val_loss: 2.5847 - val_acc: 0.2587
#
# Epoch 00001: val_acc improved from -inf to 0.25870, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0061538462.
# 390/390 [==============================] - 28s 71ms/step - loss: 1.6376 - acc: 0.5015 - val_loss: 1.7284 - val_acc: 0.5072
#
# Epoch 00002: val_acc improved from 0.25870 to 0.50720, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.005.
# 390/390 [==============================] - 27s 70ms/step - loss: 1.4589 - acc: 0.5763 - val_loss: 2.1556 - val_acc: 0.3882
#
# Epoch 00003: val_acc did not improve from 0.50720
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0042105263.
# 390/390 [==============================] - 28s 71ms/step - loss: 1.3573 - acc: 0.6186 - val_loss: 1.3784 - val_acc: 0.6185
#
# Epoch 00004: val_acc improved from 0.50720 to 0.61850, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0036363636.
# 390/390 [==============================] - 27s 70ms/step - loss: 1.2598 - acc: 0.6545 - val_loss: 1.5655 - val_acc: 0.5887
#
# Epoch 00005: val_acc did not improve from 0.61850
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0032.
# 390/390 [==============================] - 27s 70ms/step - loss: 1.1850 - acc: 0.6798 - val_loss: 1.4781 - val_acc: 0.6037
#
# Epoch 00006: val_acc did not improve from 0.61850
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0028571429.
# 390/390 [==============================] - 27s 70ms/step - loss: 1.1237 - acc: 0.6997 - val_loss: 2.6428 - val_acc: 0.4414
#
# Epoch 00007: val_acc did not improve from 0.61850
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0025806452.
# 390/390 [==============================] - 27s 70ms/step - loss: 1.0810 - acc: 0.7113 - val_loss: 1.6220 - val_acc: 0.5936
#
# Epoch 00008: val_acc did not improve from 0.61850
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0023529412.
# 390/390 [==============================] - 27s 70ms/step - loss: 1.0200 - acc: 0.7308 - val_loss: 1.8228 - val_acc: 0.5762
#
# Epoch 00009: val_acc did not improve from 0.61850
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0021621622.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.9834 - acc: 0.7397 - val_loss: 1.1843 - val_acc: 0.6832
#
# Epoch 00010: val_acc improved from 0.61850 to 0.68320, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.002.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.9501 - acc: 0.7485 - val_loss: 1.2657 - val_acc: 0.6738
#
# Epoch 00011: val_acc did not improve from 0.68320
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0018604651.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.9147 - acc: 0.7603 - val_loss: 1.7164 - val_acc: 0.5970
#
# Epoch 00012: val_acc did not improve from 0.68320
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0017391304.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.8857 - acc: 0.7692 - val_loss: 1.1828 - val_acc: 0.7085
#
# Epoch 00013: val_acc improved from 0.68320 to 0.70850, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0016326531.
# 390/390 [==============================] - 28s 71ms/step - loss: 0.8537 - acc: 0.7807 - val_loss: 1.0499 - val_acc: 0.7414
#
# Epoch 00014: val_acc improved from 0.70850 to 0.74140, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0015384615.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.8330 - acc: 0.7855 - val_loss: 1.5192 - val_acc: 0.6160
#
# Epoch 00015: val_acc did not improve from 0.74140
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0014545455.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.8084 - acc: 0.7915 - val_loss: 1.0171 - val_acc: 0.7382
#
# Epoch 00016: val_acc did not improve from 0.74140
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0013793103.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.7850 - acc: 0.7984 - val_loss: 0.9995 - val_acc: 0.7515
#
# Epoch 00017: val_acc improved from 0.74140 to 0.75150, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0013114754.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.7701 - acc: 0.8029 - val_loss: 0.9124 - val_acc: 0.7688
#
# Epoch 00018: val_acc improved from 0.75150 to 0.76880, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00125.
# 390/390 [==============================] - 28s 71ms/step - loss: 0.7425 - acc: 0.8108 - val_loss: 0.8597 - val_acc: 0.7803
#
# Epoch 00019: val_acc improved from 0.76880 to 0.78030, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0011940299.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.7343 - acc: 0.8137 - val_loss: 1.2010 - val_acc: 0.7178
#
# Epoch 00020: val_acc did not improve from 0.78030
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0011428571.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.7129 - acc: 0.8197 - val_loss: 0.9769 - val_acc: 0.7494
#
# Epoch 00021: val_acc did not improve from 0.78030
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0010958904.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.7040 - acc: 0.8230 - val_loss: 0.9965 - val_acc: 0.7541
#
# Epoch 00022: val_acc did not improve from 0.78030
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0010526316.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.6862 - acc: 0.8282 - val_loss: 1.0561 - val_acc: 0.7371
#
# Epoch 00023: val_acc did not improve from 0.78030
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0010126582.
# 390/390 [==============================] - 27s 68ms/step - loss: 0.6766 - acc: 0.8289 - val_loss: 0.8405 - val_acc: 0.7878
#
# Epoch 00024: val_acc improved from 0.78030 to 0.78780, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0009756098.
# 390/390 [==============================] - 27s 68ms/step - loss: 0.6559 - acc: 0.8360 - val_loss: 0.7973 - val_acc: 0.8056
#
# Epoch 00025: val_acc improved from 0.78780 to 0.80560, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0009411765.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.6509 - acc: 0.8343 - val_loss: 0.7604 - val_acc: 0.8113
#
# Epoch 00026: val_acc improved from 0.80560 to 0.81130, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0009090909.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.6303 - acc: 0.8424 - val_loss: 0.8361 - val_acc: 0.7859
#
# Epoch 00027: val_acc did not improve from 0.81130
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0008791209.
# 390/390 [==============================] - 27s 68ms/step - loss: 0.6285 - acc: 0.8432 - val_loss: 0.7746 - val_acc: 0.8112
#
# Epoch 00028: val_acc did not improve from 0.81130
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.0008510638.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.6174 - acc: 0.8470 - val_loss: 0.7820 - val_acc: 0.8084
#
# Epoch 00029: val_acc did not improve from 0.81130
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0008247423.
# 390/390 [==============================] - 28s 71ms/step - loss: 0.6023 - acc: 0.8511 - val_loss: 0.8696 - val_acc: 0.7868
#
# Epoch 00030: val_acc did not improve from 0.81130
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0008.
# 390/390 [==============================] - 28s 72ms/step - loss: 0.5929 - acc: 0.8544 - val_loss: 0.8030 - val_acc: 0.8027
#
# Epoch 00031: val_acc did not improve from 0.81130
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.000776699.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.5861 - acc: 0.8568 - val_loss: 0.7840 - val_acc: 0.8051
#
# Epoch 00032: val_acc did not improve from 0.81130
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.000754717.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.5791 - acc: 0.8580 - val_loss: 1.0420 - val_acc: 0.7607
#
# Epoch 00033: val_acc did not improve from 0.81130
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.000733945.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.5728 - acc: 0.8578 - val_loss: 0.8762 - val_acc: 0.7829
#
# Epoch 00034: val_acc did not improve from 0.81130
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0007142857.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.5585 - acc: 0.8619 - val_loss: 0.8826 - val_acc: 0.7820
#
# Epoch 00035: val_acc did not improve from 0.81130
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0006956522.
# 390/390 [==============================] - 28s 71ms/step - loss: 0.5583 - acc: 0.8624 - val_loss: 0.7121 - val_acc: 0.8281
#
# Epoch 00036: val_acc improved from 0.81130 to 0.82810, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0006779661.
# 390/390 [==============================] - 28s 71ms/step - loss: 0.5476 - acc: 0.8660 - val_loss: 0.8014 - val_acc: 0.8061
#
# Epoch 00037: val_acc did not improve from 0.82810
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.000661157.
# 390/390 [==============================] - 28s 71ms/step - loss: 0.5395 - acc: 0.8665 - val_loss: 0.8918 - val_acc: 0.7791
#
# Epoch 00038: val_acc did not improve from 0.82810
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0006451613.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.5290 - acc: 0.8715 - val_loss: 0.7463 - val_acc: 0.8147
#
# Epoch 00039: val_acc did not improve from 0.82810
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0006299213.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.5299 - acc: 0.8693 - val_loss: 0.8111 - val_acc: 0.8079
#
# Epoch 00040: val_acc did not improve from 0.82810
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0006153846.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.5173 - acc: 0.8740 - val_loss: 0.8421 - val_acc: 0.7979
#
# Epoch 00041: val_acc did not improve from 0.82810
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0006015038.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.5109 - acc: 0.8747 - val_loss: 0.8678 - val_acc: 0.7957
#
# Epoch 00042: val_acc did not improve from 0.82810
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0005882353.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.5108 - acc: 0.8739 - val_loss: 0.7123 - val_acc: 0.8277
#
# Epoch 00043: val_acc did not improve from 0.82810
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0005755396.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4933 - acc: 0.8808 - val_loss: 0.8745 - val_acc: 0.7859
#
# Epoch 00044: val_acc did not improve from 0.82810
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0005633803.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4971 - acc: 0.8799 - val_loss: 0.7155 - val_acc: 0.8226
#
# Epoch 00045: val_acc did not improve from 0.82810
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0005517241.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4947 - acc: 0.8796 - val_loss: 0.7593 - val_acc: 0.8173
#
# Epoch 00046: val_acc did not improve from 0.82810
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0005405405.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4886 - acc: 0.8815 - val_loss: 0.7713 - val_acc: 0.8213
#
# Epoch 00047: val_acc did not improve from 0.82810
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0005298013.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4801 - acc: 0.8831 - val_loss: 0.8666 - val_acc: 0.7968
#
# Epoch 00048: val_acc did not improve from 0.82810
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0005194805.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4728 - acc: 0.8857 - val_loss: 1.1624 - val_acc: 0.7426
#
# Epoch 00049: val_acc did not improve from 0.82810
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.0005095541.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4722 - acc: 0.8852 - val_loss: 0.9497 - val_acc: 0.7923
#
# Epoch 00050: val_acc did not improve from 0.82810
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0005.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4628 - acc: 0.8900 - val_loss: 0.6666 - val_acc: 0.8389
#
# Epoch 00051: val_acc improved from 0.82810 to 0.83890, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0004907975.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4656 - acc: 0.8898 - val_loss: 0.7948 - val_acc: 0.8153
#
# Epoch 00052: val_acc did not improve from 0.83890
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0004819277.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4548 - acc: 0.8907 - val_loss: 0.8020 - val_acc: 0.8203
#
# Epoch 00053: val_acc did not improve from 0.83890
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0004733728.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4541 - acc: 0.8925 - val_loss: 0.6343 - val_acc: 0.8493
#
# Epoch 00054: val_acc improved from 0.83890 to 0.84930, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0004651163.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4451 - acc: 0.8950 - val_loss: 0.7095 - val_acc: 0.8424
#
# Epoch 00055: val_acc did not improve from 0.84930
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0004571429.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4397 - acc: 0.8956 - val_loss: 0.6864 - val_acc: 0.8342
#
# Epoch 00056: val_acc did not improve from 0.84930
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0004494382.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4372 - acc: 0.8961 - val_loss: 0.9865 - val_acc: 0.7879
#
# Epoch 00057: val_acc did not improve from 0.84930
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.000441989.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4386 - acc: 0.8960 - val_loss: 0.8008 - val_acc: 0.8178
#
# Epoch 00058: val_acc did not improve from 0.84930
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0004347826.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4312 - acc: 0.8975 - val_loss: 0.7350 - val_acc: 0.8292
#
# Epoch 00059: val_acc did not improve from 0.84930
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0004278075.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4252 - acc: 0.9007 - val_loss: 0.6704 - val_acc: 0.8420
#
# Epoch 00060: val_acc did not improve from 0.84930
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0004210526.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4188 - acc: 0.9003 - val_loss: 0.7752 - val_acc: 0.8207
#
# Epoch 00061: val_acc did not improve from 0.84930
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0004145078.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4205 - acc: 0.9024 - val_loss: 0.7083 - val_acc: 0.8344
#
# Epoch 00062: val_acc did not improve from 0.84930
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0004081633.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4169 - acc: 0.9017 - val_loss: 0.8158 - val_acc: 0.8206
#
# Epoch 00063: val_acc did not improve from 0.84930
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0004020101.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4160 - acc: 0.9017 - val_loss: 0.7591 - val_acc: 0.8189
#
# Epoch 00064: val_acc did not improve from 0.84930
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0003960396.
# 390/390 [==============================] - 28s 71ms/step - loss: 0.4016 - acc: 0.9067 - val_loss: 0.7644 - val_acc: 0.8321
#
# Epoch 00065: val_acc did not improve from 0.84930
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0003902439.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4095 - acc: 0.9029 - val_loss: 0.6959 - val_acc: 0.8413
#
# Epoch 00066: val_acc did not improve from 0.84930
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0003846154.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3987 - acc: 0.9067 - val_loss: 0.7486 - val_acc: 0.8290
#
# Epoch 00067: val_acc did not improve from 0.84930
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0003791469.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3969 - acc: 0.9075 - val_loss: 0.7723 - val_acc: 0.8236
#
# Epoch 00068: val_acc did not improve from 0.84930
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0003738318.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3987 - acc: 0.9080 - val_loss: 0.6746 - val_acc: 0.8434
#
# Epoch 00069: val_acc did not improve from 0.84930
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0003686636.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3952 - acc: 0.9077 - val_loss: 0.7209 - val_acc: 0.8405
#
# Epoch 00070: val_acc did not improve from 0.84930
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0003636364.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3872 - acc: 0.9111 - val_loss: 0.6874 - val_acc: 0.8469
#
# Epoch 00071: val_acc did not improve from 0.84930
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0003587444.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3842 - acc: 0.9116 - val_loss: 0.6519 - val_acc: 0.8471
#
# Epoch 00072: val_acc did not improve from 0.84930
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0003539823.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3802 - acc: 0.9127 - val_loss: 0.6253 - val_acc: 0.8562
#
# Epoch 00073: val_acc improved from 0.84930 to 0.85620, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.000349345.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3778 - acc: 0.9130 - val_loss: 0.8527 - val_acc: 0.8131
#
# Epoch 00074: val_acc did not improve from 0.85620
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0003448276.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3743 - acc: 0.9136 - val_loss: 0.8565 - val_acc: 0.8140
#
# Epoch 00075: val_acc did not improve from 0.85620
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.0003404255.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3779 - acc: 0.9126 - val_loss: 0.7611 - val_acc: 0.8333
#
# Epoch 00076: val_acc did not improve from 0.85620
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.0003361345.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3723 - acc: 0.9138 - val_loss: 0.7672 - val_acc: 0.8300
#
# Epoch 00077: val_acc did not improve from 0.85620
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.0003319502.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3683 - acc: 0.9154 - val_loss: 0.6968 - val_acc: 0.8418
#
# Epoch 00078: val_acc did not improve from 0.85620
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.0003278689.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3673 - acc: 0.9153 - val_loss: 0.7488 - val_acc: 0.8345
#
# Epoch 00079: val_acc did not improve from 0.85620
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.0003238866.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3613 - acc: 0.9180 - val_loss: 0.7655 - val_acc: 0.8366
#
# Epoch 00080: val_acc did not improve from 0.85620
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.00032.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3599 - acc: 0.9192 - val_loss: 0.6785 - val_acc: 0.8424
#
# Epoch 00081: val_acc did not improve from 0.85620
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.0003162055.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3631 - acc: 0.9179 - val_loss: 0.7254 - val_acc: 0.8416
#
# Epoch 00082: val_acc did not improve from 0.85620
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.0003125.
# 390/390 [==============================] - 28s 71ms/step - loss: 0.3529 - acc: 0.9199 - val_loss: 0.7250 - val_acc: 0.8341
#
# Epoch 00083: val_acc did not improve from 0.85620
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.0003088803.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3560 - acc: 0.9188 - val_loss: 0.6537 - val_acc: 0.8645
#
# Epoch 00084: val_acc improved from 0.85620 to 0.86450, saving model to ../content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.0003053435.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3458 - acc: 0.9213 - val_loss: 0.6279 - val_acc: 0.8608
#
# Epoch 00085: val_acc did not improve from 0.86450
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.0003018868.
# 390/390 [==============================] - 28s 71ms/step - loss: 0.3464 - acc: 0.9205 - val_loss: 0.7028 - val_acc: 0.8413
#
# Epoch 00086: val_acc did not improve from 0.86450
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.0002985075.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3478 - acc: 0.9212 - val_loss: 0.7213 - val_acc: 0.8438
#
# Epoch 00087: val_acc did not improve from 0.86450
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.000295203.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3398 - acc: 0.9237 - val_loss: 0.7621 - val_acc: 0.8425
#
# Epoch 00088: val_acc did not improve from 0.86450
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.0002919708.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3425 - acc: 0.9218 - val_loss: 0.6816 - val_acc: 0.8531
#
# Epoch 00089: val_acc did not improve from 0.86450
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.0002888087.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3400 - acc: 0.9243 - val_loss: 0.7471 - val_acc: 0.8355
#
# Epoch 00090: val_acc did not improve from 0.86450
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.0002857143.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3396 - acc: 0.9231 - val_loss: 0.7500 - val_acc: 0.8406
#
# Epoch 00091: val_acc did not improve from 0.86450
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler setting learning rate to 0.0002826855.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3379 - acc: 0.9243 - val_loss: 0.7521 - val_acc: 0.8352
#
# Epoch 00092: val_acc did not improve from 0.86450
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler setting learning rate to 0.0002797203.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3305 - acc: 0.9266 - val_loss: 0.7263 - val_acc: 0.8453
#
# Epoch 00093: val_acc did not improve from 0.86450
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler setting learning rate to 0.0002768166.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.3308 - acc: 0.9259 - val_loss: 0.6403 - val_acc: 0.8606
#
# Epoch 00094: val_acc did not improve from 0.86450
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler setting learning rate to 0.0002739726.
# 390/390 [==============================] - 27s 70ms/step - loss: 0.3320 - acc: 0.9256 - val_loss: 0.6940 - val_acc: 0.8479
#
# Epoch 00095: val_acc did not improve from 0.86450
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler setting learning rate to 0.0002711864.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.3260 - acc: 0.9266 - val_loss: 0.6919 - val_acc: 0.8524
#
# Epoch 00096: val_acc did not improve from 0.86450
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler setting learning rate to 0.0002684564.
# 390/390 [==============================] - 27s 68ms/step - loss: 0.3272 - acc: 0.9272 - val_loss: 0.7742 - val_acc: 0.8316
#
# Epoch 00097: val_acc did not improve from 0.86450
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler setting learning rate to 0.0002657807.
# 390/390 [==============================] - 27s 69ms/step - loss: 0.3266 - acc: 0.9279 - val_loss: 0.6612 - val_acc: 0.8554
#
# Epoch 00098: val_acc did not improve from 0.86450
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler setting learning rate to 0.0002631579.
# 390/390 [==============================] - 28s 71ms/step - loss: 0.3238 - acc: 0.9274 - val_loss: 0.6564 - val_acc: 0.8560
#
# Epoch 00099: val_acc did not improve from 0.86450
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler setting learning rate to 0.0002605863.
# 390/390 [==============================] - 28s 72ms/step - loss: 0.3154 - acc: 0.9302 - val_loss: 0.7522 - val_acc: 0.8404
#
# Epoch 00100: val_acc did not improve from 0.86450
# Model took 2743.71 seconds to train
# Accuracy on test data is: 84.04

# %% [markdown]
# ## Saving the trained model and weights to google drive

# %%
# Save the trained weights in to .h5 format
file_name_to_save_model = "6A_model_final_retrained.h5"
file_name_to_save_model_weights = "6A_final_retrained.h5"
model.save("/content/drive/My Drive/EVA/Saved_models/"+file_name_to_save_model)
model.save_weights("/content/drive/My Drive/EVA/Saved_models/"+file_name_to_save_model_weights)
print("Saved model to drive")
# Out:
# Saved model to drive

# %% [markdown]
# ## Saving trained model and weights locally

# %%
model.save(file_name_to_save_model)
model.save_weights(file_name_to_save_model_weights)

# %%
score = model.evaluate(test_features, test_labels, batch_size=128)
print (score[1])
# Out:
# 10000/10000 [==============================] - 1s 123us/step
# 0.8404

# %%
from keras.models import load_model

model_new = load_model('/content/drive/My Drive/EVA/Saved_models/6A_retrained_best_weights.h5')

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
score = model_new.evaluate(test_features, test_labels, batch_size=128)
print (score[1])
# Out:
# 10000/10000 [==============================] - 2s 160us/step
# 0.8645
